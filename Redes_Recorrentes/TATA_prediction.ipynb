# %% [markdown]
# Previsão de ações de uma consultoria "TATA" (Exercício FIAP).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dropout, LSTM, Dense
from tensorflow.keras.metrics import R2Score
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
# Out:
# 2025-05-03 13:47:27.823874: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746290847.840760  102436 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746290847.845735  102436 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746290847.860712  102436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746290847.860735  102436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746290847.860737  102436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746290847.860738  102436 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-03 13:47:27.865566: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Verificando uso da GPU
import tensorflow as tf
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Visualização dos dados

# %%
#df = pd.read_csv('Bitcoin_19_05_2012-18_05_2013_historical_data_coinmarketcap.csv', sep=';')
df = pd.read_csv('LSTM_TATA_train.csv', sep=',')
df.sort_values(ascending=True, by='Date', inplace=True) # Ordena do menor valor de timestamp para o maior
df.head()
# Out:
#                      timeOpen                 timeClose  \
# 626  2013-04-22T00:00:00.000Z  2013-04-28T23:59:59.999Z
# 625  2013-04-29T00:00:00.000Z  2013-05-05T23:59:59.999Z
# 624  2013-05-06T00:00:00.000Z  2013-05-12T23:59:59.999Z
# 623  2013-05-13T00:00:00.000Z  2013-05-19T23:59:59.999Z
# 622  2013-05-20T00:00:00.000Z  2013-05-26T23:59:59.999Z
#
#                      timeHigh                   timeLow  name        open  \
# 626  2013-04-28T18:50:02.000Z  2013-04-28T20:15:02.000Z  2781  135.300003
# 625  2013-04-29T13:15:01.000Z  2013-05-03T03:05:01.000Z  2781  134.444000
# 624  2013-05-06T14:25:01.000Z  2013-05-07T14:35:02.000Z  2781  115.980003
# 623  2013-05-17T17:40:02.000Z  2013-05-15T00:25:01.000Z  2781  114.820000
# 622  2013-05-26T15:15:02.000Z  2013-05-20T04:45:03.000Z  2781  122.500000
#
#            high         low       close  volume     marketCap  \
# 626  135.979996  132.100006  134.210007     0.0  1.488567e+09
# 625  147.488007   79.099998  115.910004     0.0  1.288693e+09
# 624  124.663002   97.699997  115.000000     0.0  1.281983e+09
# 623  125.300003  103.500000  121.989998     0.0  1.363205e+09
# 622  136.000000  120.120003  133.479996     0.0  1.495293e+09
#
#                     timestamp
# 626  2013-04-28T23:59:59.999Z
# 625  2013-05-05T23:59:59.999Z
# 624  2013-05-12T23:59:59.999Z
# 623  2013-05-19T23:59:59.999Z
# 622  2013-05-26T23:59:59.999Z

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2035 entries, 2034 to 0
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 143.1+ KB

# %%
plt.figure(figsize=(12,6))
plt.title('Histórico Tata')
sns.lineplot(data=df, x='Date', y='Close')
plt.xticks(df['Date'][-1:0:-50], rotation=45) # Exibe o eixo x de 50 em 50
plt.xlabel('Time Close')
plt.ylabel('Valor US$')
# Out:
# Text(0, 0.5, 'Valor US$')

# %% [markdown]
# ### Pré-processamento dos dados de séries temporais

# %%
# Criando uma função para realizar a preparação de séries temporais de forma manual
def window_view(array, n_length):
    X, y = [], []

    # O loop começara com n_length
    for i in range(n_length, len(array)):

        # Faz uma subtração com a iteração atual e a quantidade de passos
        X.append(array[i-n_length:i]) # Janela de entrada
        y.append(array[i]) # Valor de saída 

    return np.array(X), np.array(y)

# %%
training_set = df['Close'].values # Adquirindo os valores de fechamento para treinamento da série temporal
training_set[0:10]
# Out:
# array([121.55, 120.9 , 120.65, 117.6 , 118.65, 118.25, 116.6 , 116.05,
#        117.3 , 118.3 ])

# %%
training_set.reshape(-1, 1).shape
# Out:
# (2035, 1)

# %% [markdown]
# Normalização dos dados

# %%
mm = MinMaxScaler()
training_set_scaled = mm.fit_transform(training_set.reshape(-1, 1))

# %%
training_set_scaled[0:10]
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        [0.14971405],
#        [0.15400327],
#        [0.15236928],
#        [0.14562908],
#        [0.14338235],
#        [0.14848856],
#        [0.15257353]])

# %% [markdown]
# Divisão dos dados em treino e validação.

# %%
y_train, y_val = train_test_split(training_set_scaled, test_size=0.2, shuffle=False)
#y_val, y_test = train_test_split(y_temp, test_size=0.4, shuffle=False)

# %%
WINDOW_LENGHT = 50

# %%
X_train_ts, y_train_ts = window_view(y_train, WINDOW_LENGHT)
X_val_ts, y_val_ts = window_view(y_val, WINDOW_LENGHT)
#X_test_ts, y_test_ts = window_view(y_test, WINDOW_LENGHT)

# %%
X_train_ts.shape # 2D (samples, timesteps)
# Out:
# (1578, 50, 1)

# %%
# Transformando em matriz (3 dimensões) para ser compatível com a entrada da rede neural
X_train_ts = X_train_ts.reshape(X_train_ts.shape[0], X_train_ts.shape[1], 1)
X_val_ts = X_val_ts.reshape(X_val_ts.shape[0], X_val_ts.shape[1], 1)
#X_test_ts = X_test_ts.reshape(X_test_ts.shape[0], X_test_ts.shape[1], 1)

# %%
X_train_ts.shape # 3D (samples, timesteps, features)
# samples: número de exemplos no batch (ou dataset)
# timesteps: número de passos temporais (ou tamanho da janela)
# features: número de variáveis por passo (por tempo)
# Out:
# (1578, 50, 1)

# %% [markdown]
# ### Criação da arquitetura da rede neural recorrente

# %%
model = Sequential([
    LSTM(units=50,
         return_sequences=True, # Garante que a camada LSTM retorne uma sequência completa (shape (batch_size, timesteps, units))
         input_shape=(X_train_ts.shape[1], X_train_ts.shape[2])), # Define como qtd de passos e qtd de features
    Dropout(0.2),
    
    LSTM(units=50,
         return_sequences=True),
    Dropout(0.2),
    
    LSTM(units=50,
         return_sequences=True),
    Dropout(0.2),
    
    LSTM(units=50),
    Dropout(0.2),
    
    Dense(units=1) # Caso não for especificado a função de ativação, será "linear"
])
# Out:
# I0000 00:00:1746290852.097126  102436 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6102 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2060 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5
# /home/wolf/anaconda3/envs/ai_env/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss=MeanSquaredError(),
              optimizer=RMSprop(learning_rate=0.0001),
              metrics=[R2Score()])

# %%
callbacks = [EarlyStopping(monitor='val_loss', patience=10),
             ModelCheckpoint(monitor='val_loss',
                             filepath='best_model_recurrent_LSTM.keras',
                             save_best_only=True),
             ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10)]

# %%
history = model.fit(X_train_ts, y_train_ts,
                    batch_size=32,
                    validation_data=(X_val_ts, y_val_ts),
                    callbacks=callbacks,
                    epochs=100)
# Out:
# Epoch 1/100
# I0000 00:00:1746290854.858532  102523 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - loss: 0.0246 - r2_score: -1.8620 - val_loss: 0.0680 - val_r2_score: -0.6218 - learning_rate: 1.0000e-04
# Epoch 2/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0031 - r2_score: 0.6111 - val_loss: 0.0314 - val_r2_score: 0.2499 - learning_rate: 1.0000e-04
# Epoch 3/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0022 - r2_score: 0.7369 - val_loss: 0.0257 - val_r2_score: 0.3859 - learning_rate: 1.0000e-04
# Epoch 4/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s -1182074us/step - loss: 0.0020 - r2_score: 0.7550 - val_loss: 0.0172 - val_r2_score: 0.5904 - learning_rate: 1.0000e-04
# Epoch 5/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0020 - r2_score: 0.7474 - val_loss: 0.0230 - val_r2_score: 0.4511 - learning_rate: 1.0000e-04
# Epoch 6/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0020 - r2_score: 0.7586 - val_loss: 0.0214 - val_r2_score: 0.4888 - learning_rate: 1.0000e-04
# Epoch 7/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s -1180883us/step - loss: 0.0018 - r2_score: 0.7854 - val_loss: 0.0198 - val_r2_score: 0.5276 - learning_rate: 1.0000e-04
# Epoch 8/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0017 - r2_score: 0.7986 - val_loss: 0.0180 - val_r2_score: 0.5695 - learning_rate: 1.0000e-04
# Epoch 9/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0018 - r2_score: 0.7868 - val_loss: 0.0167 - val_r2_score: 0.6014 - learning_rate: 1.0000e-04
# Epoch 10/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0017 - r2_score: 0.7983 - val_loss: 0.0181 - val_r2_score: 0.5691 - learning_rate: 1.0000e-04
# Epoch 11/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0017 - r2_score: 0.7999 - val_loss: 0.0162 - val_r2_score: 0.6129 - learning_rate: 1.0000e-04
# Epoch 12/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0017 - r2_score: 0.7932 - val_loss: 0.0155 - val_r2_score: 0.6299 - learning_rate: 1.0000e-04
# Epoch 13/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s -1184310us/step - loss: 0.0017 - r2_score: 0.7897 - val_loss: 0.0165 - val_r2_score: 0.6051 - learning_rate: 1.0000e-04
# Epoch 14/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0016 - r2_score: 0.8116 - val_loss: 0.0120 - val_r2_score: 0.7139 - learning_rate: 1.0000e-04
# Epoch 15/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0016 - r2_score: 0.8044 - val_loss: 0.0155 - val_r2_score: 0.6312 - learning_rate: 1.0000e-04
# Epoch 16/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0015 - r2_score: 0.8206 - val_loss: 0.0112 - val_r2_score: 0.7323 - learning_rate: 1.0000e-04
# Epoch 17/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 0.0015 - r2_score: 0.8180 - val_loss: 0.0097 - val_r2_score: 0.7678 - learning_rate: 1.0000e-04
# Epoch 18/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0016 - r2_score: 0.8046 - val_loss: 0.0181 - val_r2_score: 0.5684 - learning_rate: 1.0000e-04
# Epoch 19/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0016 - r2_score: 0.7959 - val_loss: 0.0133 - val_r2_score: 0.6830 - learning_rate: 1.0000e-04
# Epoch 20/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0015 - r2_score: 0.8178 - val_loss: 0.0132 - val_r2_score: 0.6861 - learning_rate: 1.0000e-04
# Epoch 21/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0015 - r2_score: 0.8204 - val_loss: 0.0119 - val_r2_score: 0.7155 - learning_rate: 1.0000e-04
# Epoch 22/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s -1181877us/step - loss: 0.0016 - r2_score: 0.8174 - val_loss: 0.0098 - val_r2_score: 0.7663 - learning_rate: 1.0000e-04
# Epoch 23/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0016 - r2_score: 0.8138 - val_loss: 0.0147 - val_r2_score: 0.6484 - learning_rate: 1.0000e-04
# Epoch 24/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0015 - r2_score: 0.8171 - val_loss: 0.0094 - val_r2_score: 0.7760 - learning_rate: 1.0000e-04
# Epoch 25/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0015 - r2_score: 0.8047 - val_loss: 0.0136 - val_r2_score: 0.6754 - learning_rate: 1.0000e-04
# Epoch 26/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - r2_score: 0.8328 - val_loss: 0.0095 - val_r2_score: 0.7724 - learning_rate: 1.0000e-04
# Epoch 27/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - r2_score: 0.8361 - val_loss: 0.0124 - val_r2_score: 0.7048 - learning_rate: 1.0000e-04
# Epoch 28/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0014 - r2_score: 0.8236 - val_loss: 0.0119 - val_r2_score: 0.7166 - learning_rate: 1.0000e-04
# Epoch 29/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0014 - r2_score: 0.8324 - val_loss: 0.0107 - val_r2_score: 0.7452 - learning_rate: 1.0000e-04
# Epoch 30/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0016 - r2_score: 0.8038 - val_loss: 0.0093 - val_r2_score: 0.7783 - learning_rate: 1.0000e-04
# Epoch 31/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0014 - r2_score: 0.8317 - val_loss: 0.0123 - val_r2_score: 0.7069 - learning_rate: 1.0000e-04
# Epoch 32/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0013 - r2_score: 0.8453 - val_loss: 0.0087 - val_r2_score: 0.7935 - learning_rate: 1.0000e-04
# Epoch 33/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0014 - r2_score: 0.8286 - val_loss: 0.0125 - val_r2_score: 0.7013 - learning_rate: 1.0000e-04
# Epoch 34/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0014 - r2_score: 0.8332 - val_loss: 0.0081 - val_r2_score: 0.8061 - learning_rate: 1.0000e-04
# Epoch 35/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - r2_score: 0.8434 - val_loss: 0.0112 - val_r2_score: 0.7321 - learning_rate: 1.0000e-04
# Epoch 36/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0014 - r2_score: 0.8311 - val_loss: 0.0116 - val_r2_score: 0.7231 - learning_rate: 1.0000e-04
# Epoch 37/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0014 - r2_score: 0.8213 - val_loss: 0.0092 - val_r2_score: 0.7797 - learning_rate: 1.0000e-04
# Epoch 38/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s -1183953us/step - loss: 0.0014 - r2_score: 0.8270 - val_loss: 0.0104 - val_r2_score: 0.7528 - learning_rate: 1.0000e-04
# Epoch 39/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0013 - r2_score: 0.8361 - val_loss: 0.0122 - val_r2_score: 0.7099 - learning_rate: 1.0000e-04
# Epoch 40/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - r2_score: 0.8483 - val_loss: 0.0102 - val_r2_score: 0.7575 - learning_rate: 1.0000e-04
# Epoch 41/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - r2_score: 0.8411 - val_loss: 0.0072 - val_r2_score: 0.8278 - learning_rate: 1.0000e-04
# Epoch 42/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0012 - r2_score: 0.8511 - val_loss: 0.0095 - val_r2_score: 0.7728 - learning_rate: 1.0000e-04
# Epoch 43/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0013 - r2_score: 0.8397 - val_loss: 0.0081 - val_r2_score: 0.8078 - learning_rate: 1.0000e-04
# Epoch 44/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s 33ms/step - loss: 0.0012 - r2_score: 0.8541 - val_loss: 0.0086 - val_r2_score: 0.7955 - learning_rate: 1.0000e-04
# Epoch 45/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - r2_score: 0.8479 - val_loss: 0.0097 - val_r2_score: 0.7674 - learning_rate: 1.0000e-04
# Epoch 46/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 61s 1s/step - loss: 0.0013 - r2_score: 0.8451 - val_loss: 0.0069 - val_r2_score: 0.8342 - learning_rate: 1.0000e-04
# Epoch 47/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ -58s 31ms/step - loss: 0.0013 - r2_score: 0.8388 - val_loss: 0.0116 - val_r2_score: 0.7232 - learning_rate: 1.0000e-04
# Epoch 48/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0012 - r2_score: 0.8579 - val_loss: 0.0094 - val_r2_score: 0.7752 - learning_rate: 1.0000e-04
# Epoch 49/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0013 - r2_score: 0.8507 - val_loss: 0.0089 - val_r2_score: 0.7865 - learning_rate: 1.0000e-04
# Epoch 50/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0012 - r2_score: 0.8566 - val_loss: 0.0107 - val_r2_score: 0.7447 - learning_rate: 1.0000e-04
# Epoch 51/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - r2_score: 0.8481 - val_loss: 0.0100 - val_r2_score: 0.7605 - learning_rate: 1.0000e-04
# Epoch 52/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0012 - r2_score: 0.8539 - val_loss: 0.0092 - val_r2_score: 0.7805 - learning_rate: 1.0000e-04
# Epoch 53/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0012 - r2_score: 0.8542 - val_loss: 0.0080 - val_r2_score: 0.8080 - learning_rate: 1.0000e-04
# Epoch 54/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0012 - r2_score: 0.8487 - val_loss: 0.0087 - val_r2_score: 0.7926 - learning_rate: 1.0000e-04
# Epoch 55/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.0011 - r2_score: 0.8585 - val_loss: 0.0076 - val_r2_score: 0.8182 - learning_rate: 1.0000e-04
# Epoch 56/100
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0012 - r2_score: 0.8606 - val_loss: 0.0080 - val_r2_score: 0.8081 - learning_rate: 1.0000e-04

# %%
def view_history(model_history):
    plt.figure(figsize=(12,6))
    plt.subplot(1,2,1)
    plt.title("R² por época")
    plt.plot(model_history.history['r2_score'])
    plt.plot(model_history.history['val_r2_score'])
    plt.legend(['Treino', 'Validação'])
    plt.xlabel("Época")
    plt.ylabel("R²")
    
    plt.subplot(1,2,2)
    plt.title("Perda por época")
    plt.plot(model_history.history['loss'])
    plt.plot(model_history.history['val_loss'])
    plt.legend(['Treino', 'Validação'])
    plt.xlabel("Época")
    plt.ylabel("Perda")

# %%
view_history(history)

# %% [markdown]
# Predição dos dados de validação para verificar como o modelo se ajustou as variações de preço.

# %%
y_val_predicts = model.predict(X_val_ts)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step

# %% [markdown]
# Voltando aos valores de preço originais (não escalados/normalizados com MinMaxScaler).

# %%
y_val = mm.inverse_transform(y_val)
y_val_predicts = mm.inverse_transform(y_val_predicts)

# %%
# Exibindo dados reais x dados previstos (inferidos, predição)
sns.lineplot(x='Date', y=y_val[:,0], data=df[len(y_train):len(df)], label='Valores esperados')
sns.lineplot(x='Date', y=y_val_predicts[:,0], data=df[len(y_train) + WINDOW_LENGHT:len(df)], label='Predição')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Conclusão
#
# Este é um modelo simples que prevê o valor futuro de ações baseado **apenas na série histórica das ações** da mesma empresa. Na prática, a predição de valores financeiros é influenciada por uma série de fatores externos relativos ao mercado e à economia. Portanto, o nosso modelo por mais que foi capaz de captar as tendências de variações de preço das ações, ainda não performou tão bem, pois previu os valores bem abaixo dos valores reais e de forma bem imprecisa.
